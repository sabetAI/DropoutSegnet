# %% [markdown]
# # Visual results (pixel-wise class predictions and model uncertainty)

# %% [markdown]
# ## Description

# %% [markdown]
# In this notebook, the main results of our best model are generated. Class label predictions and model uncertainty for different images in the train, validation and test datasets are presented. The method *visual_results* from the *SegNet* class which is imported in the first code line of this notebook, outputs a segmented image and uncertainty map for samples. The "visual_results" method can take three arguments:
# 1. ***dataset_type***: A string indicating the dataset type (either "TRAIN", "VAL" or "TEST"). By default it is "TEST".
# 2. ***images_index***: A list indicating the images indexes from the corresponding dataset. For instance, if we pass the list [0,20,47] we are requesting the prediction for the images that are found in the indexes 0, 20 and 47 of the dataset. This parameter can also be an integer value which corresponds to the number of different images that we want to display. In this case, we randomly pick the specified number of images from the corresponding dataset. By default it is set to 3.
# 3. ***FLAG_MAX_VOTE***: A boolean parameter indicating whether we want to use Max Voting (True) or Mean (False) at test time for the Bayesian model. By default it is set to False.
#
# For each of the displayed images we show (1) the original image, (2) the ground truth, i.e., the given pixel labels for training the network and obtain prediction accuracies, (3) the output of our model for the given image, and (4) the uncertainty of the model prediction (the darker the color is, the more uncertain the prediction in this pixel is).
#
# Finally, we also show the color legend for the different classes.

# %% [markdown]
# ## Installation

# %% [markdown]
# #### install anaconda package manager, then run
# $ conda install tensorflow-gpu
# #### should prompt to install the following packages:
# cudatoolkit-8.0
#
# cudnn-7.0.5
#
# tensorflow-gpu-1.4.1
#
# tensorflow-gpu-base-1.4.1

# %% [markdown]
# ## Import

# %%
from SegNet import SegNet
from drawings_object import display_color_legend

# %% [markdown]
# ## Train dataset (367 images)

# %%
from tensorflow.python.client import device_lib

# gpu should be listed as an available device
device_lib.list_local_devices()
# Out:
# [name: "/device:CPU:0"
#  device_type: "CPU"
#  memory_limit: 268435456
#  locality {
#  }
#  incarnation: 5532985262475875652, name: "/device:GPU:0"
#  device_type: "GPU"
#  memory_limit: 2656632832
#  locality {
#    bus_id: 1
#  }
#  incarnation: 16677350874919621664
#  physical_device_desc: "device: 0, name: GeForce GTX 770M, pci bus id: 0000:01:00.0, compute capability: 3.0"]

# %%
SegNet().test()
# Out:
# VGG parameter loaded
# INFO:tensorflow:Restoring parameters from ./segnet_vgg_bayes_MFL_17000/model.ckpt-17000
# 233 CamVid test images are loaded
# (1, 360, 480, 12)
# Image Index 0: TEST Loss 0.334, TEST Accu  0.931
# accuracy = 0.931198
# mean IU  = 0.760222
#     class # 0 accuracy = 0.951272
#     class # 1 accuracy = 0.907278
#     class # 2 accuracy = 0.387612
#     class # 3 accuracy = 0.984857
#     class # 4 accuracy = 0.835739
#     class # 5 accuracy = 0.940609
#     class # 6 accuracy = 0.910345
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.977083
#     class # 9 accuracy = 0.807832
#     class # 10 accuracy = 0.988812
#     class # 11 accuracy = 0.859400
# /home/alicapwn/Documents/project/Dropout_SegNet/evaluation_object.py:98: RuntimeWarning: invalid value encountered in true_divide
#   iu = np.diag(hist) / (hist.sum(1) + hist.sum(0) - np.diag(hist))
# (1, 360, 480, 12)
# Image Index 1: TEST Loss 0.408, TEST Accu  0.923
# accuracy = 0.923333
# mean IU  = 0.748253
#     class # 0 accuracy = 0.964756
#     class # 1 accuracy = 0.919301
#     class # 2 accuracy = 0.426316
#     class # 3 accuracy = 0.979893
#     class # 4 accuracy = 0.744828
#     class # 5 accuracy = 0.893751
#     class # 6 accuracy = 0.884278
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.982961
#     class # 9 accuracy = 0.510204
#     class # 10 accuracy = 0.978504
#     class # 11 accuracy = 0.882058
# (1, 360, 480, 12)
# Image Index 2: TEST Loss 0.483, TEST Accu  0.895
# accuracy = 0.895237
# mean IU  = 0.690264
#     class # 0 accuracy = 0.920882
#     class # 1 accuracy = 0.832941
#     class # 2 accuracy = 0.301179
#     class # 3 accuracy = 0.981606
#     class # 4 accuracy = 0.931502
#     class # 5 accuracy = 0.880568
#     class # 6 accuracy = 0.409091
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.988745
#     class # 9 accuracy = 0.873039
#     class # 10 accuracy = 0.931201
#     class # 11 accuracy = 0.747922
# (1, 360, 480, 12)
# Image Index 3: TEST Loss 0.541, TEST Accu  0.883
# accuracy = 0.882841
# mean IU  = 0.654599
#     class # 0 accuracy = 0.918743
#     class # 1 accuracy = 0.638367
#     class # 2 accuracy = 0.592226
#     class # 3 accuracy = 0.980408
#     class # 4 accuracy = 0.806797
#     class # 5 accuracy = 0.919785
#     class # 6 accuracy = 0.413793
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.929807
#     class # 9 accuracy = 0.590000
#     class # 10 accuracy = 0.970197
#     class # 11 accuracy = 0.821500
# (1, 360, 480, 12)
# Image Index 4: TEST Loss 0.906, TEST Accu  0.854
# accuracy = 0.853872
# mean IU  = 0.641342
#     class # 0 accuracy = 0.733081
#     class # 1 accuracy = 0.797086
#     class # 2 accuracy = 0.382698
#     class # 3 accuracy = 0.974783
#     class # 4 accuracy = 0.928739
#     class # 5 accuracy = 0.879471
#     class # 6 accuracy = 0.311628
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.944816
#     class # 9 accuracy = 0.774356
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.772060
# (1, 360, 480, 12)
# Image Index 5: TEST Loss 0.650, TEST Accu  0.898
# accuracy = 0.898466
# mean IU  = 0.577246
#     class # 0 accuracy = 0.903334
#     class # 1 accuracy = 0.873139
#     class # 2 accuracy = 0.405220
#     class # 3 accuracy = 0.971045
#     class # 4 accuracy = 0.925223
#     class # 5 accuracy = 0.913603
#     class # 6 accuracy = 0.101983
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.951780
#     class # 9 accuracy = 0.582278
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.774205
# (1, 360, 480, 12)
# Image Index 6: TEST Loss 0.541, TEST Accu  0.901
# accuracy = 0.900816
# mean IU  = 0.613936
#     class # 0 accuracy = 0.921982
#     class # 1 accuracy = 0.872977
#     class # 2 accuracy = 0.269155
#     class # 3 accuracy = 0.942832
#     class # 4 accuracy = 0.923741
#     class # 5 accuracy = 0.922851
#     class # 6 accuracy = 0.646667
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.930322
#     class # 9 accuracy = 0.611376
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.831160
# (1, 360, 480, 12)
# Image Index 7: TEST Loss 1.353, TEST Accu  0.844
# accuracy = 0.844381
# mean IU  = 0.595287
#     class # 0 accuracy = 0.928456
#     class # 1 accuracy = 0.851980
#     class # 2 accuracy = 0.352941
#     class # 3 accuracy = 0.806396
#     class # 4 accuracy = 0.853896
#     class # 5 accuracy = 0.847101
#     class # 6 accuracy = 0.625000
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.970254
#     class # 9 accuracy = 0.450516
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.742891
# (1, 360, 480, 12)
# Image Index 8: TEST Loss 1.249, TEST Accu  0.859
# accuracy = 0.859097
# mean IU  = 0.612940
#     class # 0 accuracy = 0.956348
#     class # 1 accuracy = 0.789421
#     class # 2 accuracy = 0.182553
#     class # 3 accuracy = 0.800654
#     class # 4 accuracy = 0.881353
#     class # 5 accuracy = 0.900881
#     class # 6 accuracy = 0.673621
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.965379
#     class # 9 accuracy = 0.568976
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.716797
# (1, 360, 480, 12)
# Image Index 9: TEST Loss 0.969, TEST Accu  0.864
# accuracy = 0.863924
# mean IU  = 0.668907
#     class # 0 accuracy = 0.925222
#     class # 1 accuracy = 0.716366
#     class # 2 accuracy = 0.330744
#     class # 3 accuracy = 0.859822
#     class # 4 accuracy = 0.941093
#     class # 5 accuracy = 0.917845
#     class # 6 accuracy = 0.716312
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.933665
#     class # 9 accuracy = 0.779247
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.688589
# (1, 360, 480, 12)
# Image Index 10: TEST Loss 0.862, TEST Accu  0.867
# accuracy = 0.867425
# mean IU  = 0.650192
#     class # 0 accuracy = 0.914273
#     class # 1 accuracy = 0.791130
#     class # 2 accuracy = 0.547909
#     class # 3 accuracy = 0.979464
#     class # 4 accuracy = 0.943288
#     class # 5 accuracy = 0.879358
#     class # 6 accuracy = 0.541774
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.963588
#     class # 9 accuracy = 0.218358
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.685373
# (1, 360, 480, 12)
# Image Index 11: TEST Loss 0.862, TEST Accu  0.869
# accuracy = 0.868663
# mean IU  = 0.635715
#     class # 0 accuracy = 0.934054
#     class # 1 accuracy = 0.779023
#     class # 2 accuracy = 0.279939
#     class # 3 accuracy = 0.985889
#     class # 4 accuracy = 0.934264
#     class # 5 accuracy = 0.910174
#     class # 6 accuracy = 0.751739
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.942597
#     class # 9 accuracy = 0.640636
#     class # 10 accuracy = 0.220552
#     class # 11 accuracy = 0.666987
# (1, 360, 480, 12)
# Image Index 12: TEST Loss 0.663, TEST Accu  0.876
# accuracy = 0.876395
# mean IU  = 0.649328
#     class # 0 accuracy = 0.891614
#     class # 1 accuracy = 0.694506
#     class # 2 accuracy = 0.374046
#     class # 3 accuracy = 0.976844
#     class # 4 accuracy = 0.955267
#     class # 5 accuracy = 0.930159
#     class # 6 accuracy = 0.192698
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.908797
#     class # 9 accuracy = 0.637255
#     class # 10 accuracy = 0.966616
#     class # 11 accuracy = 0.617744
# (1, 360, 480, 12)
# Image Index 13: TEST Loss 0.590, TEST Accu  0.890
# accuracy = 0.889676
# mean IU  = 0.677297
#     class # 0 accuracy = 0.934294
#     class # 1 accuracy = 0.773119
#     class # 2 accuracy = 0.413681
#     class # 3 accuracy = 0.980115
#     class # 4 accuracy = 0.966310
#     class # 5 accuracy = 0.897680
#     class # 6 accuracy = 0.476303
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.884639
#     class # 9 accuracy = 0.470137
#     class # 10 accuracy = 0.962977
#     class # 11 accuracy = 0.726911
# (1, 360, 480, 12)
# Image Index 14: TEST Loss 0.626, TEST Accu  0.892
# accuracy = 0.891921
# mean IU  = 0.639121
#     class # 0 accuracy = 0.967180
#     class # 1 accuracy = 0.770832
#     class # 2 accuracy = 0.452282
#     class # 3 accuracy = 0.977654
#     class # 4 accuracy = 0.966938
#     class # 5 accuracy = 0.899421
#     class # 6 accuracy = 0.775244
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.829556
#     class # 9 accuracy = 0.346108
#     class # 10 accuracy = 0.960537
#     class # 11 accuracy = 0.756783
# (1, 360, 480, 12)
# Image Index 15: TEST Loss 1.198, TEST Accu  0.835
# accuracy = 0.834682
# mean IU  = 0.642429
#     class # 0 accuracy = 0.915269
#     class # 1 accuracy = 0.791800
#     class # 2 accuracy = 0.402730
#     class # 3 accuracy = 0.990191
#     class # 4 accuracy = 0.946707
#     class # 5 accuracy = 0.921158
#     class # 6 accuracy = 0.735849
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.596113
#     class # 9 accuracy = 0.780405
#     class # 10 accuracy = 0.911466
#     class # 11 accuracy = 0.649260
# (1, 360, 480, 12)
# Image Index 16: TEST Loss 1.684, TEST Accu  0.811
# accuracy = 0.810799
# mean IU  = 0.562717
#     class # 0 accuracy = 0.885656
#     class # 1 accuracy = 0.865621
#     class # 2 accuracy = 0.401989
#     class # 3 accuracy = 0.981941
#     class # 4 accuracy = 0.960176
#     class # 5 accuracy = 0.943449
#     class # 6 accuracy = 0.726708
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.576947
#     class # 9 accuracy = 0.655422
#     class # 10 accuracy = 0.049743
#     class # 11 accuracy = 0.611178
# (1, 360, 480, 12)
# Image Index 17: TEST Loss 2.417, TEST Accu  0.808
# accuracy = 0.808362
# mean IU  = 0.568561
#     class # 0 accuracy = 0.957597
#     class # 1 accuracy = 0.851663
#     class # 2 accuracy = 0.325749
#     class # 3 accuracy = 0.983945
#     class # 4 accuracy = 0.958750
#     class # 5 accuracy = 0.898197
#     class # 6 accuracy = 0.625749
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.484599
#     class # 9 accuracy = 0.400120
#     class # 10 accuracy = 0.278954
#     class # 11 accuracy = 0.762793
# (1, 360, 480, 12)
# Image Index 18: TEST Loss 2.117, TEST Accu  0.818
# accuracy = 0.818137
# mean IU  = 0.611241
#     class # 0 accuracy = 0.944293
#     class # 1 accuracy = 0.721575
#     class # 2 accuracy = 0.364848
#     class # 3 accuracy = 0.973872
#     class # 4 accuracy = 0.957500
#     class # 5 accuracy = 0.931973
#     class # 6 accuracy = 0.614068
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.520869
#     class # 9 accuracy = 0.361192
#     class # 10 accuracy = 0.912446
#     class # 11 accuracy = 0.688832
# (1, 360, 480, 12)
# Image Index 19: TEST Loss 1.658, TEST Accu  0.825
# accuracy = 0.824838
# mean IU  = 0.602280
#     class # 0 accuracy = 0.937849
#     class # 1 accuracy = 0.719452
#     class # 2 accuracy = 0.413655
#     class # 3 accuracy = 0.979742
#     class # 4 accuracy = 0.961080
#     class # 5 accuracy = 0.913974
#     class # 6 accuracy = 0.741284
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.598560
#     class # 9 accuracy = 0.290956
#     class # 10 accuracy = 0.581543
#     class # 11 accuracy = 0.641817
# (1, 360, 480, 12)
# Image Index 20: TEST Loss 1.379, TEST Accu  0.829
# accuracy = 0.828756
# mean IU  = 0.549902
#     class # 0 accuracy = 0.903288
#     class # 1 accuracy = 0.704607
#     class # 2 accuracy = 0.417314
#     class # 3 accuracy = 0.966994
#     class # 4 accuracy = 0.974574
#     class # 5 accuracy = 0.929782
#     class # 6 accuracy = 0.722222
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.628287
#     class # 9 accuracy = 0.273625
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.701986
# (1, 360, 480, 12)
# Image Index 21: TEST Loss 0.865, TEST Accu  0.873
# accuracy = 0.872795
# mean IU  = 0.587688
#     class # 0 accuracy = 0.940915
#     class # 1 accuracy = 0.729127
#     class # 2 accuracy = 0.349763
#     class # 3 accuracy = 0.964498
#     class # 4 accuracy = 0.910182
#     class # 5 accuracy = 0.966693
#     class # 6 accuracy = 0.683564
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.783445
#     class # 9 accuracy = 0.461635
#     class # 10 accuracy = 0.011364
#     class # 11 accuracy = 0.765576
# (1, 360, 480, 12)
# Image Index 22: TEST Loss 1.006, TEST Accu  0.868
# accuracy = 0.868137
# mean IU  = 0.593349
#     class # 0 accuracy = 0.957693
#     class # 1 accuracy = 0.710157
#     class # 2 accuracy = 0.363184
#     class # 3 accuracy = 0.982406
#     class # 4 accuracy = 0.957768
#     class # 5 accuracy = 0.950844
#     class # 6 accuracy = 0.654979
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.724044
#     class # 9 accuracy = 0.843481
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.602632
# (1, 360, 480, 12)
# Image Index 23: TEST Loss 0.866, TEST Accu  0.882
# accuracy = 0.882141
# mean IU  = 0.648526
#     class # 0 accuracy = 0.945594
#     class # 1 accuracy = 0.731052
#     class # 2 accuracy = 0.410695
#     class # 3 accuracy = 0.973449
#     class # 4 accuracy = 0.935186
#     class # 5 accuracy = 0.982546
#     class # 6 accuracy = 0.687237
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.836027
#     class # 9 accuracy = 0.453675
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.658051
# (1, 360, 480, 12)
# Image Index 24: TEST Loss 1.104, TEST Accu  0.864
# accuracy = 0.864433
# mean IU  = 0.603164
#     class # 0 accuracy = 0.900479
#     class # 1 accuracy = 0.742615
#     class # 2 accuracy = 0.338664
#     class # 3 accuracy = 0.984244
#     class # 4 accuracy = 0.932381
#     class # 5 accuracy = 0.969888
#     class # 6 accuracy = 0.676218
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.739717
#     class # 9 accuracy = 0.882924
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.607140
# (1, 360, 480, 12)
# Image Index 25: TEST Loss 1.104, TEST Accu  0.863
# accuracy = 0.862523
# mean IU  = 0.598480
#     class # 0 accuracy = 0.912577
#     class # 1 accuracy = 0.755853
#     class # 2 accuracy = 0.353091
#     class # 3 accuracy = 0.986755
#     class # 4 accuracy = 0.941521
#     class # 5 accuracy = 0.960032
#     class # 6 accuracy = 0.643537
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.730151
#     class # 9 accuracy = 0.868842
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.608948
# (1, 360, 480, 12)
# Image Index 26: TEST Loss 1.054, TEST Accu  0.861
# accuracy = 0.860862
# mean IU  = 0.597427
#     class # 0 accuracy = 0.899981
#     class # 1 accuracy = 0.716150
#     class # 2 accuracy = 0.406604
#     class # 3 accuracy = 0.982357
#     class # 4 accuracy = 0.945869
#     class # 5 accuracy = 0.960165
#     class # 6 accuracy = 0.623482
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.765833
#     class # 9 accuracy = 0.781215
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.604031
# (1, 360, 480, 12)
# Image Index 27: TEST Loss 1.150, TEST Accu  0.856
# accuracy = 0.855943
# mean IU  = 0.603610
#     class # 0 accuracy = 0.896672
#     class # 1 accuracy = 0.747285
#     class # 2 accuracy = 0.417733
#     class # 3 accuracy = 0.984448
#     class # 4 accuracy = 0.926390
#     class # 5 accuracy = 0.945559
#     class # 6 accuracy = 0.695238
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.728190
#     class # 9 accuracy = 0.891878
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.627733
# (1, 360, 480, 12)
# Image Index 28: TEST Loss 1.063, TEST Accu  0.865
# accuracy = 0.865405
# mean IU  = 0.598419
#     class # 0 accuracy = 0.928010
#     class # 1 accuracy = 0.706869
#     class # 2 accuracy = 0.393673
#     class # 3 accuracy = 0.983962
#     class # 4 accuracy = 0.926430
#     class # 5 accuracy = 0.961756
#     class # 6 accuracy = 0.646530
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.745107
#     class # 9 accuracy = 0.951394
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.614998
# (1, 360, 480, 12)
# Image Index 29: TEST Loss 0.988, TEST Accu  0.870
# accuracy = 0.869884
# mean IU  = 0.614617
#     class # 0 accuracy = 0.910393
#     class # 1 accuracy = 0.713543
#     class # 2 accuracy = 0.438822
#     class # 3 accuracy = 0.985705
#     class # 4 accuracy = 0.934758
#     class # 5 accuracy = 0.967441
#     class # 6 accuracy = 0.613184
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.773489
#     class # 9 accuracy = 0.943979
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.624583
# (1, 360, 480, 12)
# Image Index 30: TEST Loss 0.999, TEST Accu  0.872
# accuracy = 0.871510
# mean IU  = 0.616907
#     class # 0 accuracy = 0.939136
#     class # 1 accuracy = 0.709491
#     class # 2 accuracy = 0.389307
#     class # 3 accuracy = 0.984823
#     class # 4 accuracy = 0.956753
#     class # 5 accuracy = 0.962140
#     class # 6 accuracy = 0.654402
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.742144
#     class # 9 accuracy = 0.806357
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.640124
# (1, 360, 480, 12)
# Image Index 31: TEST Loss 0.970, TEST Accu  0.873
# accuracy = 0.873281
# mean IU  = 0.621058
#     class # 0 accuracy = 0.922304
#     class # 1 accuracy = 0.711415
#     class # 2 accuracy = 0.442418
#     class # 3 accuracy = 0.987045
#     class # 4 accuracy = 0.919388
#     class # 5 accuracy = 0.962653
#     class # 6 accuracy = 0.721358
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.769340
#     class # 9 accuracy = 0.897629
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.640280
# (1, 360, 480, 12)
# Image Index 32: TEST Loss 0.877, TEST Accu  0.873
# accuracy = 0.873050
# mean IU  = 0.629844
#     class # 0 accuracy = 0.905378
#     class # 1 accuracy = 0.665226
#     class # 2 accuracy = 0.507752
#     class # 3 accuracy = 0.964495
#     class # 4 accuracy = 0.931194
#     class # 5 accuracy = 0.961524
#     class # 6 accuracy = 0.700787
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.811412
#     class # 9 accuracy = 0.816603
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.658258
# (1, 360, 480, 12)
# Image Index 33: TEST Loss 0.611, TEST Accu  0.899
# accuracy = 0.899485
# mean IU  = 0.662301
#     class # 0 accuracy = 0.948110
#     class # 1 accuracy = 0.676680
#     class # 2 accuracy = 0.510934
#     class # 3 accuracy = 0.970091
#     class # 4 accuracy = 0.914782
#     class # 5 accuracy = 0.954824
#     class # 6 accuracy = 0.835772
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.941443
#     class # 9 accuracy = 0.846873
#     class # 10 accuracy = 0.767756
#     class # 11 accuracy = 0.683470
# (1, 360, 480, 12)
# Image Index 34: TEST Loss 0.783, TEST Accu  0.894
# accuracy = 0.893669
# mean IU  = 0.641966
#     class # 0 accuracy = 0.944059
#     class # 1 accuracy = 0.718533
#     class # 2 accuracy = 0.474722
#     class # 3 accuracy = 0.966936
#     class # 4 accuracy = 0.926744
#     class # 5 accuracy = 0.960933
#     class # 6 accuracy = 0.717914
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.710494
#     class # 9 accuracy = 0.798867
#     class # 10 accuracy = 0.857477
#     class # 11 accuracy = 0.732304
# (1, 360, 480, 12)
# Image Index 35: TEST Loss 0.706, TEST Accu  0.883
# accuracy = 0.882737
# mean IU  = 0.641584
#     class # 0 accuracy = 0.905947
#     class # 1 accuracy = 0.754045
#     class # 2 accuracy = 0.333791
#     class # 3 accuracy = 0.968467
#     class # 4 accuracy = 0.929841
#     class # 5 accuracy = 0.961072
#     class # 6 accuracy = 0.684160
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.627448
#     class # 9 accuracy = 0.914701
#     class # 10 accuracy = 0.968697
#     class # 11 accuracy = 0.803607
# (1, 360, 480, 12)
# Image Index 36: TEST Loss 0.926, TEST Accu  0.857
# accuracy = 0.856730
# mean IU  = 0.596978
#     class # 0 accuracy = 0.984801
#     class # 1 accuracy = 0.743494
#     class # 2 accuracy = 0.466463
#     class # 3 accuracy = 0.973175
#     class # 4 accuracy = 0.957288
#     class # 5 accuracy = 0.939003
#     class # 6 accuracy = 0.688870
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.585587
#     class # 9 accuracy = 0.544950
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.772117
# (1, 360, 480, 12)
# Image Index 37: TEST Loss 2.772, TEST Accu  0.737
# accuracy = 0.736644
# mean IU  = 0.518440
#     class # 0 accuracy = 0.982280
#     class # 1 accuracy = 0.856727
#     class # 2 accuracy = 0.527633
#     class # 3 accuracy = 0.961386
#     class # 4 accuracy = 0.977388
#     class # 5 accuracy = 0.895723
#     class # 6 accuracy = 0.903321
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.233116
#     class # 9 accuracy = 0.524882
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.797676
# (1, 360, 480, 12)
# Image Index 38: TEST Loss 1.869, TEST Accu  0.824
# accuracy = 0.824444
# mean IU  = 0.560106
#     class # 0 accuracy = 0.977012
#     class # 1 accuracy = 0.844399
#     class # 2 accuracy = 0.513352
#     class # 3 accuracy = 0.947682
#     class # 4 accuracy = 0.971365
#     class # 5 accuracy = 0.813256
#     class # 6 accuracy = 0.799107
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.584962
#     class # 9 accuracy = 0.630244
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.833486
# (1, 360, 480, 12)
# Image Index 39: TEST Loss 1.969, TEST Accu  0.805
# accuracy = 0.805116
# mean IU  = 0.504393
#     class # 0 accuracy = 0.961691
#     class # 1 accuracy = 0.792356
#     class # 2 accuracy = 0.583870
#     class # 3 accuracy = 0.982586
#     class # 4 accuracy = 0.929189
#     class # 5 accuracy = 0.757418
#     class # 6 accuracy = 0.211199
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.471482
#     class # 9 accuracy = 0.810469
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.834167
# (1, 360, 480, 12)
# Image Index 40: TEST Loss 0.483, TEST Accu  0.911
# accuracy = 0.910949
# mean IU  = 0.692880
#     class # 0 accuracy = 0.920085
#     class # 1 accuracy = 0.900716
#     class # 2 accuracy = 0.641495
#     class # 3 accuracy = 0.984879
#     class # 4 accuracy = 0.973195
#     class # 5 accuracy = 0.904723
#     class # 6 accuracy = 0.901454
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.938141
#     class # 9 accuracy = 0.753983
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.824385
# (1, 360, 480, 12)
# Image Index 41: TEST Loss 0.566, TEST Accu  0.894
# accuracy = 0.893657
# mean IU  = 0.655772
#     class # 0 accuracy = 0.957020
#     class # 1 accuracy = 0.892197
#     class # 2 accuracy = 0.372183
#     class # 3 accuracy = 0.986564
#     class # 4 accuracy = 0.919497
#     class # 5 accuracy = 0.811664
#     class # 6 accuracy = 0.937250
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.946848
#     class # 9 accuracy = 0.730045
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.741621
# (1, 360, 480, 12)
# Image Index 42: TEST Loss 0.339, TEST Accu  0.931
# accuracy = 0.930966
# mean IU  = 0.620300
#     class # 0 accuracy = 0.988028
#     class # 1 accuracy = 0.930432
#     class # 2 accuracy = 0.232143
#     class # 3 accuracy = 0.985112
#     class # 4 accuracy = 0.895214
#     class # 5 accuracy = 0.876292
#     class # 6 accuracy = 0.903226
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.975543
#     class # 9 accuracy = 0.797820
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.755177
# (1, 360, 480, 12)
# Image Index 43: TEST Loss 0.534, TEST Accu  0.913
# accuracy = 0.912963
# mean IU  = 0.606800
#     class # 0 accuracy = 0.980535
#     class # 1 accuracy = 0.902038
#     class # 2 accuracy = 0.252229
#     class # 3 accuracy = 0.982979
#     class # 4 accuracy = 0.923744
#     class # 5 accuracy = 0.812304
#     class # 6 accuracy = 0.940933
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.978629
#     class # 9 accuracy = 0.703686
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.810639
# (1, 360, 480, 12)
# Image Index 44: TEST Loss 0.612, TEST Accu  0.883
# accuracy = 0.882674
# mean IU  = 0.587268
#     class # 0 accuracy = 0.986218
#     class # 1 accuracy = 0.788542
#     class # 2 accuracy = 0.534545
#     class # 3 accuracy = 0.982484
#     class # 4 accuracy = 0.932118
#     class # 5 accuracy = 0.778457
#     class # 6 accuracy = 0.804325
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.985280
#     class # 9 accuracy = 0.736609
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.657767
# (1, 360, 480, 12)
# Image Index 45: TEST Loss 0.748, TEST Accu  0.873
# accuracy = 0.873119
# mean IU  = 0.563828
#     class # 0 accuracy = 0.987083
#     class # 1 accuracy = 0.762256
#     class # 2 accuracy = 0.430440
#     class # 3 accuracy = 0.976374
#     class # 4 accuracy = 0.933682
#     class # 5 accuracy = 0.832515
#     class # 6 accuracy = 0.929368
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.942651
#     class # 9 accuracy = 0.552555
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.672276
# (1, 360, 480, 12)
# Image Index 46: TEST Loss 1.082, TEST Accu  0.843
# accuracy = 0.842940
# mean IU  = 0.586963
#     class # 0 accuracy = 0.982361
#     class # 1 accuracy = 0.742263
#     class # 2 accuracy = 0.549172
#     class # 3 accuracy = 0.990745
#     class # 4 accuracy = 0.881625
#     class # 5 accuracy = 0.881576
#     class # 6 accuracy = 0.971411
#     class # 7 accuracy = 0.000224
#     class # 8 accuracy = 0.972394
#     class # 9 accuracy = 0.597583
#     class # 10 accuracy = 0.153061
#     class # 11 accuracy = 0.653549
# (1, 360, 480, 12)
# Image Index 47: TEST Loss 0.716, TEST Accu  0.885
# accuracy = 0.885422
# mean IU  = 0.605413
#     class # 0 accuracy = 0.982343
#     class # 1 accuracy = 0.900377
#     class # 2 accuracy = 0.364996
#     class # 3 accuracy = 0.987297
#     class # 4 accuracy = 0.812579
#     class # 5 accuracy = 0.897763
#     class # 6 accuracy = 0.945902
#     class # 7 accuracy = 0.268483
#     class # 8 accuracy = 0.967117
#     class # 9 accuracy = 0.087649
#     class # 10 accuracy = 0.623141
#     class # 11 accuracy = 0.716927
# (1, 360, 480, 12)
# Image Index 48: TEST Loss 1.478, TEST Accu  0.800
# accuracy = 0.800469
# mean IU  = 0.394014
#     class # 0 accuracy = 0.000000
#     class # 1 accuracy = 0.820280
#     class # 2 accuracy = 0.000000
#     class # 3 accuracy = 0.989955
#     class # 4 accuracy = 0.777017
#     class # 5 accuracy = 0.864964
#     class # 6 accuracy = 0.762827
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.000000
#     class # 9 accuracy = 0.839051
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.711948
# (1, 360, 480, 12)
# Image Index 49: TEST Loss 0.613, TEST Accu  0.888
# accuracy = 0.888067
# mean IU  = 0.698227
#     class # 0 accuracy = 0.990866
#     class # 1 accuracy = 0.932415
#     class # 2 accuracy = 0.882081
#     class # 3 accuracy = 0.979488
#     class # 4 accuracy = 0.850662
#     class # 5 accuracy = 0.843935
#     class # 6 accuracy = 0.184701
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.882414
#     class # 9 accuracy = 0.000000
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.576494
# (1, 360, 480, 12)
# Image Index 50: TEST Loss 1.032, TEST Accu  0.832
# accuracy = 0.832488
# mean IU  = 0.510919
#     class # 0 accuracy = 0.983363
#     class # 1 accuracy = 0.596119
#     class # 2 accuracy = 0.074561
#     class # 3 accuracy = 0.957883
#     class # 4 accuracy = 0.855718
#     class # 5 accuracy = 0.878865
#     class # 6 accuracy = 0.000000
#     class # 7 accuracy = 0.801114
#     class # 8 accuracy = 0.977680
#     class # 9 accuracy = 0.052083
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.507662
# (1, 360, 480, 12)
# Image Index 51: TEST Loss 1.123, TEST Accu  0.860
# accuracy = 0.859537
# mean IU  = 0.513676
#     class # 0 accuracy = 0.984961
#     class # 1 accuracy = 0.549574
#     class # 2 accuracy = 0.047658
#     class # 3 accuracy = 0.982476
#     class # 4 accuracy = 0.952749
#     class # 5 accuracy = 0.953100
#     class # 6 accuracy = 0.000000
#     class # 7 accuracy = 0.025421
#     class # 8 accuracy = 0.967530
#     class # 9 accuracy = 0.220430
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.842160
# (1, 360, 480, 12)
# Image Index 52: TEST Loss 1.553, TEST Accu  0.821
# accuracy = 0.820671
# mean IU  = 0.479823
#     class # 0 accuracy = 0.985065
#     class # 1 accuracy = 0.502901
#     class # 2 accuracy = 0.052062
#     class # 3 accuracy = 0.974077
#     class # 4 accuracy = 0.906447
#     class # 5 accuracy = 0.886284
#     class # 6 accuracy = 0.000000
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.990730
#     class # 9 accuracy = 0.061674
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.888220
# (1, 360, 480, 12)
# Image Index 53: TEST Loss 1.692, TEST Accu  0.799
# accuracy = 0.798646
# mean IU  = 0.508733
#     class # 0 accuracy = 0.969032
#     class # 1 accuracy = 0.571353
#     class # 2 accuracy = 0.077265
#     class # 3 accuracy = 0.976576
#     class # 4 accuracy = 0.955771
#     class # 5 accuracy = 0.820260
#     class # 6 accuracy = 0.141221
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.976711
#     class # 9 accuracy = 0.203931
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.841845
# (1, 360, 480, 12)
# Image Index 54: TEST Loss 1.767, TEST Accu  0.810
# accuracy = 0.810168
# mean IU  = 0.533139
#     class # 0 accuracy = 0.969578
#     class # 1 accuracy = 0.596678
#     class # 2 accuracy = 0.028681
#     class # 3 accuracy = 0.964111
#     class # 4 accuracy = 0.939524
#     class # 5 accuracy = 0.885214
#     class # 6 accuracy = 0.700000
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.981231
#     class # 9 accuracy = 0.300108
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.904967
# (1, 360, 480, 12)
# Image Index 55: TEST Loss 1.584, TEST Accu  0.805
# accuracy = 0.804855
# mean IU  = 0.515192
#     class # 0 accuracy = 0.956600
#     class # 1 accuracy = 0.686369
#     class # 2 accuracy = 0.113650
#     class # 3 accuracy = 0.966313
#     class # 4 accuracy = 0.936521
#     class # 5 accuracy = 0.858487
#     class # 6 accuracy = 0.688172
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.755334
#     class # 9 accuracy = 0.000000
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.894056
# (1, 360, 480, 12)
# Image Index 56: TEST Loss 0.651, TEST Accu  0.893
# accuracy = 0.893009
# mean IU  = 0.566877
#     class # 0 accuracy = 0.936810
#     class # 1 accuracy = 0.940587
#     class # 2 accuracy = 0.215165
#     class # 3 accuracy = 0.971338
#     class # 4 accuracy = 0.705486
#     class # 5 accuracy = 0.910561
#     class # 6 accuracy = 0.891473
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.984624
#     class # 9 accuracy = 0.000000
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.689169
# (1, 360, 480, 12)
# Image Index 57: TEST Loss 0.751, TEST Accu  0.884
# accuracy = 0.883652
# mean IU  = 0.609499
#     class # 0 accuracy = 0.947262
#     class # 1 accuracy = 0.926680
#     class # 2 accuracy = 0.210639
#     class # 3 accuracy = 0.980115
#     class # 4 accuracy = 0.830392
#     class # 5 accuracy = 0.918131
#     class # 6 accuracy = 0.941304
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.970342
#     class # 9 accuracy = 0.911392
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.681564
# (1, 360, 480, 12)
# Image Index 58: TEST Loss 1.292, TEST Accu  0.843
# accuracy = 0.842506
# mean IU  = 0.534476
#     class # 0 accuracy = 0.968527
#     class # 1 accuracy = 0.969912
#     class # 2 accuracy = 0.039125
#     class # 3 accuracy = 0.976427
#     class # 4 accuracy = 0.466362
#     class # 5 accuracy = 0.864464
#     class # 6 accuracy = 0.818844
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.946325
#     class # 9 accuracy = 0.462151
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.725417
# (1, 360, 480, 12)
# Image Index 59: TEST Loss 0.689, TEST Accu  0.896
# accuracy = 0.895868
# mean IU  = 0.554361
#     class # 0 accuracy = 0.962682
#     class # 1 accuracy = 0.905316
#     class # 2 accuracy = 0.015080
#     class # 3 accuracy = 0.975294
#     class # 4 accuracy = 0.861561
#     class # 5 accuracy = 0.947286
#     class # 6 accuracy = 0.000000
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.950386
#     class # 9 accuracy = 0.731809
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.629269
# (1, 360, 480, 12)
# Image Index 60: TEST Loss 0.728, TEST Accu  0.887
# accuracy = 0.887373
# mean IU  = 0.553178
#     class # 0 accuracy = 0.826815
#     class # 1 accuracy = 0.936022
#     class # 2 accuracy = 0.031513
#     class # 3 accuracy = 0.908784
#     class # 4 accuracy = 0.818619
#     class # 5 accuracy = 0.902074
#     class # 6 accuracy = 0.000000
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.960447
#     class # 9 accuracy = 0.834568
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.851755
# (1, 360, 480, 12)
# Image Index 61: TEST Loss 0.684, TEST Accu  0.889
# accuracy = 0.889306
# mean IU  = 0.581351
#     class # 0 accuracy = 0.953395
#     class # 1 accuracy = 0.924234
#     class # 2 accuracy = 0.056726
#     class # 3 accuracy = 0.965359
#     class # 4 accuracy = 0.876469
#     class # 5 accuracy = 0.803257
#     class # 6 accuracy = 0.000000
#     class # 7 accuracy = 0.148204
#     class # 8 accuracy = 0.958265
#     class # 9 accuracy = 0.693175
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.800591
# (1, 360, 480, 12)
# Image Index 62: TEST Loss 3.021, TEST Accu  0.641
# accuracy = 0.640955
# mean IU  = 0.413049
#     class # 0 accuracy = 0.908732
#     class # 1 accuracy = 0.813557
#     class # 2 accuracy = 0.782123
#     class # 3 accuracy = 0.997742
#     class # 4 accuracy = 0.982849
#     class # 5 accuracy = 0.959492
#     class # 6 accuracy = 0.000000
#     class # 7 accuracy = 0.119056
#     class # 8 accuracy = 0.986052
#     class # 9 accuracy = 0.000000
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.083740
# (1, 360, 480, 12)
# Image Index 63: TEST Loss 0.973, TEST Accu  0.846
# accuracy = 0.845689
# mean IU  = 0.512008
#     class # 0 accuracy = 0.826437
#     class # 1 accuracy = 0.679108
#     class # 2 accuracy = 0.514373
#     class # 3 accuracy = 0.965453
#     class # 4 accuracy = 0.977450
#     class # 5 accuracy = 0.929980
#     class # 6 accuracy = 0.005017
#     class # 7 accuracy = 0.203072
#     class # 8 accuracy = 0.971348
#     class # 9 accuracy = 0.000000
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.209125
# (1, 360, 480, 12)
# Image Index 64: TEST Loss 1.009, TEST Accu  0.829
# accuracy = 0.829433
# mean IU  = 0.526048
#     class # 0 accuracy = 0.860130
#     class # 1 accuracy = 0.462104
#     class # 2 accuracy = 0.552239
#     class # 3 accuracy = 0.981155
#     class # 4 accuracy = 0.985778
#     class # 5 accuracy = 0.947802
#     class # 6 accuracy = 0.000000
#     class # 7 accuracy = 0.249042
#     class # 8 accuracy = 0.990582
#     class # 9 accuracy = 0.512821
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.200581
# (1, 360, 480, 12)
# Image Index 65: TEST Loss 1.090, TEST Accu  0.810
# accuracy = 0.810370
# mean IU  = 0.419340
#     class # 0 accuracy = 0.953792
#     class # 1 accuracy = 0.383146
#     class # 2 accuracy = 0.182363
#     class # 3 accuracy = 0.974595
#     class # 4 accuracy = 0.957041
#     class # 5 accuracy = 0.885606
#     class # 6 accuracy = 0.014036
#     class # 7 accuracy = 0.120824
#     class # 8 accuracy = 0.972625
#     class # 9 accuracy = 0.384615
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.216283
# (1, 360, 480, 12)
# Image Index 66: TEST Loss 0.847, TEST Accu  0.856
# accuracy = 0.855550
# mean IU  = 0.500586
#     class # 0 accuracy = 0.881512
#     class # 1 accuracy = 0.604038
#     class # 2 accuracy = 0.211749
#     class # 3 accuracy = 0.979841
#     class # 4 accuracy = 0.951885
#     class # 5 accuracy = 0.907028
#     class # 6 accuracy = 0.008510
#     class # 7 accuracy = 0.229471
#     class # 8 accuracy = 0.942247
#     class # 9 accuracy = 0.244240
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.664841
# (1, 360, 480, 12)
# Image Index 67: TEST Loss 1.173, TEST Accu  0.819
# accuracy = 0.818970
# mean IU  = 0.449971
#     class # 0 accuracy = 0.819720
#     class # 1 accuracy = 0.751570
#     class # 2 accuracy = 0.225275
#     class # 3 accuracy = 0.993785
#     class # 4 accuracy = 0.465197
#     class # 5 accuracy = 0.914564
#     class # 6 accuracy = 0.011934
#     class # 7 accuracy = 0.253041
#     class # 8 accuracy = 0.945144
#     class # 9 accuracy = 0.312500
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.375687
# (1, 360, 480, 12)
# Image Index 68: TEST Loss 0.721, TEST Accu  0.885
# accuracy = 0.885353
# mean IU  = 0.494322
#     class # 0 accuracy = 0.904600
#     class # 1 accuracy = 0.588540
#     class # 2 accuracy = 0.065080
#     class # 3 accuracy = 0.984004
#     class # 4 accuracy = 0.889894
#     class # 5 accuracy = 0.917583
#     class # 6 accuracy = 0.011918
#     class # 7 accuracy = 0.521345
#     class # 8 accuracy = 0.969987
#     class # 9 accuracy = 0.000000
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.514818
# (1, 360, 480, 12)
# Image Index 69: TEST Loss 0.673, TEST Accu  0.865
# accuracy = 0.865480
# mean IU  = 0.529130
#     class # 0 accuracy = 0.949857
#     class # 1 accuracy = 0.594730
#     class # 2 accuracy = 0.154452
#     class # 3 accuracy = 0.955912
#     class # 4 accuracy = 0.921994
#     class # 5 accuracy = 0.888687
#     class # 6 accuracy = 0.044039
#     class # 7 accuracy = 0.371465
#     class # 8 accuracy = 0.970870
#     class # 9 accuracy = 0.641975
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.552159
# (1, 360, 480, 12)
# Image Index 70: TEST Loss 1.342, TEST Accu  0.803
# accuracy = 0.802917
# mean IU  = 0.434727
#     class # 0 accuracy = 0.917153
#     class # 1 accuracy = 0.567936
#     class # 2 accuracy = 0.245769
#     class # 3 accuracy = 0.988374
#     class # 4 accuracy = 0.803157
#     class # 5 accuracy = 0.984311
#     class # 6 accuracy = 0.056580
#     class # 7 accuracy = 0.427213
#     class # 8 accuracy = 0.899288
#     class # 9 accuracy = 0.265896
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.107506
# (1, 360, 480, 12)
# Image Index 71: TEST Loss 1.347, TEST Accu  0.803
# accuracy = 0.803299
# mean IU  = 0.517990
#     class # 0 accuracy = 0.977509
#     class # 1 accuracy = 0.634119
#     class # 2 accuracy = 0.165470
#     class # 3 accuracy = 0.955856
#     class # 4 accuracy = 0.976085
#     class # 5 accuracy = 0.280401
#     class # 6 accuracy = 0.482428
#     class # 7 accuracy = 0.761844
#     class # 8 accuracy = 0.972297
#     class # 9 accuracy = 0.857868
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.135307
# (1, 360, 480, 12)
# Image Index 72: TEST Loss 0.844, TEST Accu  0.858
# accuracy = 0.858351
# mean IU  = 0.600619
#     class # 0 accuracy = 0.971760
#     class # 1 accuracy = 0.876041
#     class # 2 accuracy = 0.191974
#     class # 3 accuracy = 0.989088
#     class # 4 accuracy = 0.825727
#     class # 5 accuracy = 0.591466
#     class # 6 accuracy = 0.495033
#     class # 7 accuracy = 0.533425
#     class # 8 accuracy = 0.963424
#     class # 9 accuracy = 0.905812
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.292769
# (1, 360, 480, 12)
# Image Index 73: TEST Loss 0.874, TEST Accu  0.857
# accuracy = 0.857141
# mean IU  = 0.618389
#     class # 0 accuracy = 0.980540
#     class # 1 accuracy = 0.822659
#     class # 2 accuracy = 0.553729
#     class # 3 accuracy = 0.995030
#     class # 4 accuracy = 0.699781
#     class # 5 accuracy = 0.573238
#     class # 6 accuracy = 0.607903
#     class # 7 accuracy = 0.472905
#     class # 8 accuracy = 0.984842
#     class # 9 accuracy = 0.927772
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.311597
# (1, 360, 480, 12)
# Image Index 74: TEST Loss 0.931, TEST Accu  0.865
# accuracy = 0.865087
# mean IU  = 0.594995
#     class # 0 accuracy = 0.978914
#     class # 1 accuracy = 0.861947
#     class # 2 accuracy = 0.640476
#     class # 3 accuracy = 0.985299
#     class # 4 accuracy = 0.575483
#     class # 5 accuracy = 0.740197
#     class # 6 accuracy = 0.858592
#     class # 7 accuracy = 0.341472
#     class # 8 accuracy = 0.938028
#     class # 9 accuracy = 0.734375
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.486178
# (1, 360, 480, 12)
# Image Index 75: TEST Loss 0.953, TEST Accu  0.863
# accuracy = 0.863247
# mean IU  = 0.572323
#     class # 0 accuracy = 0.980171
#     class # 1 accuracy = 0.820256
#     class # 2 accuracy = 0.761248
#     class # 3 accuracy = 0.962375
#     class # 4 accuracy = 0.923440
#     class # 5 accuracy = 0.316821
#     class # 6 accuracy = 0.873754
#     class # 7 accuracy = 0.619678
#     class # 8 accuracy = 0.926471
#     class # 9 accuracy = 0.327434
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.465144
# (1, 360, 480, 12)
# Image Index 76: TEST Loss 0.877, TEST Accu  0.884
# accuracy = 0.883704
# mean IU  = 0.491680
#     class # 0 accuracy = 0.977483
#     class # 1 accuracy = 0.908530
#     class # 2 accuracy = 0.291930
#     class # 3 accuracy = 0.906483
#     class # 4 accuracy = 0.903863
#     class # 5 accuracy = 0.560841
#     class # 6 accuracy = 0.509859
#     class # 7 accuracy = 0.196434
#     class # 8 accuracy = 0.906061
#     class # 9 accuracy = 0.790850
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.634615
# (1, 360, 480, 12)
# Image Index 77: TEST Loss 1.026, TEST Accu  0.867
# accuracy = 0.866672
# mean IU  = 0.594169
#     class # 0 accuracy = 0.983498
#     class # 1 accuracy = 0.845723
#     class # 2 accuracy = 0.551255
#     class # 3 accuracy = 0.997495
#     class # 4 accuracy = 0.499592
#     class # 5 accuracy = 0.816950
#     class # 6 accuracy = 0.906137
#     class # 7 accuracy = 0.896981
#     class # 8 accuracy = 0.890966
#     class # 9 accuracy = 0.833992
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.505703
# (1, 360, 480, 12)
# Image Index 78: TEST Loss 0.183, TEST Accu  0.956
# accuracy = 0.956036
# mean IU  = 0.627915
#     class # 0 accuracy = 0.986736
#     class # 1 accuracy = 0.932232
#     class # 2 accuracy = 0.503634
#     class # 3 accuracy = 0.991706
#     class # 4 accuracy = 0.979967
#     class # 5 accuracy = 0.930240
#     class # 6 accuracy = 0.264706
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.926667
#     class # 9 accuracy = 0.902410
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.816467
# (1, 360, 480, 12)
# Image Index 79: TEST Loss 0.378, TEST Accu  0.929
# accuracy = 0.929468
# mean IU  = 0.521458
#     class # 0 accuracy = 0.991016
#     class # 1 accuracy = 0.949427
#     class # 2 accuracy = 0.285950
#     class # 3 accuracy = 0.989685
#     class # 4 accuracy = 0.973855
#     class # 5 accuracy = 0.808875
#     class # 6 accuracy = 0.174737
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.956204
#     class # 9 accuracy = 0.669118
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.350711
# (1, 360, 480, 12)
# Image Index 80: TEST Loss 0.723, TEST Accu  0.884
# accuracy = 0.883964
# mean IU  = 0.437389
#     class # 0 accuracy = 0.977698
#     class # 1 accuracy = 0.821835
#     class # 2 accuracy = 0.278696
#     class # 3 accuracy = 0.983471
#     class # 4 accuracy = 0.966179
#     class # 5 accuracy = 0.326706
#     class # 6 accuracy = 0.344221
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.902622
#     class # 9 accuracy = 0.656716
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.347615
# (1, 360, 480, 12)
# Image Index 81: TEST Loss 0.815, TEST Accu  0.900
# accuracy = 0.900075
# mean IU  = 0.408003
#     class # 0 accuracy = 0.993792
#     class # 1 accuracy = 0.887875
#     class # 2 accuracy = 0.362129
#     class # 3 accuracy = 0.997933
#     class # 4 accuracy = 0.674656
#     class # 5 accuracy = 0.400000
#     class # 6 accuracy = 0.023899
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.804979
#     class # 9 accuracy = 0.486726
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.392109
# (1, 360, 480, 12)
# Image Index 82: TEST Loss 0.644, TEST Accu  0.898
# accuracy = 0.898108
# mean IU  = 0.519514
#     class # 0 accuracy = 0.991127
#     class # 1 accuracy = 0.843733
#     class # 2 accuracy = 0.501517
#     class # 3 accuracy = 0.995248
#     class # 4 accuracy = 0.936810
#     class # 5 accuracy = 0.612263
#     class # 6 accuracy = 0.024390
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.800781
#     class # 9 accuracy = 0.791506
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.602644
# (1, 360, 480, 12)
# Image Index 83: TEST Loss 0.588, TEST Accu  0.898
# accuracy = 0.897627
# mean IU  = 0.513491
#     class # 0 accuracy = 0.987078
#     class # 1 accuracy = 0.781867
#     class # 2 accuracy = 0.622248
#     class # 3 accuracy = 0.992531
#     class # 4 accuracy = 0.977979
#     class # 5 accuracy = 0.902552
#     class # 6 accuracy = 0.214286
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.838235
#     class # 9 accuracy = 0.783333
#     class # 10 accuracy = 0.211268
#     class # 11 accuracy = 0.667946
# (1, 360, 480, 12)
# Image Index 84: TEST Loss 0.414, TEST Accu  0.920
# accuracy = 0.920318
# mean IU  = 0.529380
#     class # 0 accuracy = 0.986529
#     class # 1 accuracy = 0.856256
#     class # 2 accuracy = 0.296616
#     class # 3 accuracy = 0.993648
#     class # 4 accuracy = 0.971909
#     class # 5 accuracy = 0.924018
#     class # 6 accuracy = 0.292089
#     class # 7 accuracy = 0.123618
#     class # 8 accuracy = 0.919094
#     class # 9 accuracy = 0.745033
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.727672
# (1, 360, 480, 12)
# Image Index 85: TEST Loss 0.908, TEST Accu  0.883
# accuracy = 0.883212
# mean IU  = 0.521164
#     class # 0 accuracy = 0.968171
#     class # 1 accuracy = 0.931854
#     class # 2 accuracy = 0.693333
#     class # 3 accuracy = 0.996937
#     class # 4 accuracy = 0.760610
#     class # 5 accuracy = 0.861550
#     class # 6 accuracy = 0.000000
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.940928
#     class # 9 accuracy = 0.893916
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.169723
# (1, 360, 480, 12)
# Image Index 86: TEST Loss 0.426, TEST Accu  0.913
# accuracy = 0.913194
# mean IU  = 0.536366
#     class # 0 accuracy = 0.980693
#     class # 1 accuracy = 0.893804
#     class # 2 accuracy = 0.517834
#     class # 3 accuracy = 0.991590
#     class # 4 accuracy = 0.959391
#     class # 5 accuracy = 0.797354
#     class # 6 accuracy = 0.014925
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.973290
#     class # 9 accuracy = 0.830000
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.580972
# (1, 360, 480, 12)
# Image Index 87: TEST Loss 0.717, TEST Accu  0.903
# accuracy = 0.903432
# mean IU  = 0.626483
#     class # 0 accuracy = 0.989168
#     class # 1 accuracy = 0.862370
#     class # 2 accuracy = 0.609361
#     class # 3 accuracy = 0.990790
#     class # 4 accuracy = 0.818748
#     class # 5 accuracy = 0.920060
#     class # 6 accuracy = 0.554622
#     class # 7 accuracy = 0.685289
#     class # 8 accuracy = 0.950000
#     class # 9 accuracy = 0.723176
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.757001
# (1, 360, 480, 12)
# Image Index 88: TEST Loss 0.412, TEST Accu  0.926
# accuracy = 0.926337
# mean IU  = 0.555814
#     class # 0 accuracy = 0.986778
#     class # 1 accuracy = 0.889023
#     class # 2 accuracy = 0.403059
#     class # 3 accuracy = 0.994261
#     class # 4 accuracy = 0.924087
#     class # 5 accuracy = 0.944862
#     class # 6 accuracy = 0.311075
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.864130
#     class # 9 accuracy = 0.804631
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.620023
# (1, 360, 480, 12)
# Image Index 89: TEST Loss 0.585, TEST Accu  0.913
# accuracy = 0.913310
# mean IU  = 0.528961
#     class # 0 accuracy = 0.985374
#     class # 1 accuracy = 0.891591
#     class # 2 accuracy = 0.584650
#     class # 3 accuracy = 0.993675
#     class # 4 accuracy = 0.958072
#     class # 5 accuracy = 0.000000
#     class # 6 accuracy = 0.557093
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.828729
#     class # 9 accuracy = 0.915945
#     class # 10 accuracy = 0.423529
# ...
#     class # 3 accuracy = 0.964373
#     class # 4 accuracy = 0.940316
#     class # 5 accuracy = 0.000000
#     class # 6 accuracy = 0.245779
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.128358
#     class # 9 accuracy = 0.726287
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.458355
# (1, 360, 480, 12)
# Image Index 204: TEST Loss 0.689, TEST Accu  0.927
# accuracy = 0.926701
# mean IU  = 0.559651
#     class # 0 accuracy = 0.988433
#     class # 1 accuracy = 0.954092
#     class # 2 accuracy = 0.112346
#     class # 3 accuracy = 0.996268
#     class # 4 accuracy = 0.914553
#     class # 5 accuracy = 0.224793
#     class # 6 accuracy = 0.741100
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.529319
#     class # 9 accuracy = 0.884810
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.239618
# (1, 360, 480, 12)
# Image Index 205: TEST Loss 0.646, TEST Accu  0.900
# accuracy = 0.899878
# mean IU  = 0.489166
#     class # 0 accuracy = 0.985911
#     class # 1 accuracy = 0.945748
#     class # 2 accuracy = 0.163816
#     class # 3 accuracy = 0.984963
#     class # 4 accuracy = 0.945980
#     class # 5 accuracy = 0.000000
#     class # 6 accuracy = 0.200772
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.238667
#     class # 9 accuracy = 0.969822
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.293201
# (1, 360, 480, 12)
# Image Index 206: TEST Loss 0.659, TEST Accu  0.912
# accuracy = 0.911534
# mean IU  = 0.539429
#     class # 0 accuracy = 0.989891
#     class # 1 accuracy = 0.962262
#     class # 2 accuracy = 0.134754
#     class # 3 accuracy = 0.989303
#     class # 4 accuracy = 0.872998
#     class # 5 accuracy = 0.000000
#     class # 6 accuracy = 0.346273
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.974416
#     class # 9 accuracy = 0.802721
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.188321
# (1, 360, 480, 12)
# Image Index 207: TEST Loss 1.026, TEST Accu  0.895
# accuracy = 0.894797
# mean IU  = 0.551705
#     class # 0 accuracy = 0.994450
#     class # 1 accuracy = 0.945090
#     class # 2 accuracy = 0.399689
#     class # 3 accuracy = 0.979092
#     class # 4 accuracy = 0.568962
#     class # 5 accuracy = 0.606061
#     class # 6 accuracy = 0.354597
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.952206
#     class # 9 accuracy = 0.896711
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.552286
# (1, 360, 480, 12)
# Image Index 208: TEST Loss 1.787, TEST Accu  0.823
# accuracy = 0.822546
# mean IU  = 0.404454
#     class # 0 accuracy = 0.992163
#     class # 1 accuracy = 0.849365
#     class # 2 accuracy = 0.149859
#     class # 3 accuracy = 0.955195
#     class # 4 accuracy = 0.395452
#     class # 5 accuracy = 0.346793
#     class # 6 accuracy = 0.416773
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.976348
#     class # 9 accuracy = 0.099715
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.362778
# (1, 360, 480, 12)
# Image Index 209: TEST Loss 1.286, TEST Accu  0.867
# accuracy = 0.866840
# mean IU  = 0.481299
#     class # 0 accuracy = 0.984480
#     class # 1 accuracy = 0.947954
#     class # 2 accuracy = 0.538918
#     class # 3 accuracy = 0.988640
#     class # 4 accuracy = 0.341200
#     class # 5 accuracy = 0.611340
#     class # 6 accuracy = 0.428401
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.000000
#     class # 9 accuracy = 0.512387
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.534088
# (1, 360, 480, 12)
# Image Index 210: TEST Loss 1.254, TEST Accu  0.839
# accuracy = 0.839450
# mean IU  = 0.493771
#     class # 0 accuracy = 0.907441
#     class # 1 accuracy = 0.798026
#     class # 2 accuracy = 0.547304
#     class # 3 accuracy = 0.986851
#     class # 4 accuracy = 0.683338
#     class # 5 accuracy = 0.679149
#     class # 6 accuracy = 0.709484
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.000000
#     class # 9 accuracy = 0.229428
#     class # 10 accuracy = 0.483438
#     class # 11 accuracy = 0.844287
# (1, 360, 480, 12)
# Image Index 211: TEST Loss 0.959, TEST Accu  0.862
# accuracy = 0.861950
# mean IU  = 0.431726
#     class # 0 accuracy = 0.983965
#     class # 1 accuracy = 0.940633
#     class # 2 accuracy = 0.335878
#     class # 3 accuracy = 0.995107
#     class # 4 accuracy = 0.562763
#     class # 5 accuracy = 0.571963
#     class # 6 accuracy = 0.460967
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.360294
#     class # 9 accuracy = 0.233608
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.539269
# (1, 360, 480, 12)
# Image Index 212: TEST Loss 0.520, TEST Accu  0.903
# accuracy = 0.902598
# mean IU  = 0.623920
#     class # 0 accuracy = 0.985663
#     class # 1 accuracy = 0.914010
#     class # 2 accuracy = 0.414996
#     class # 3 accuracy = 0.991088
#     class # 4 accuracy = 0.960563
#     class # 5 accuracy = 0.397672
#     class # 6 accuracy = 0.692122
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.729927
#     class # 9 accuracy = 0.759099
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.729937
# (1, 360, 480, 12)
# Image Index 213: TEST Loss 0.517, TEST Accu  0.903
# accuracy = 0.903449
# mean IU  = 0.526227
#     class # 0 accuracy = 0.988777
#     class # 1 accuracy = 0.872095
#     class # 2 accuracy = 0.586844
#     class # 3 accuracy = 0.982964
#     class # 4 accuracy = 0.896918
#     class # 5 accuracy = 0.705225
#     class # 6 accuracy = 0.170648
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.866397
#     class # 9 accuracy = 0.656888
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.529444
# (1, 360, 480, 12)
# Image Index 214: TEST Loss 0.589, TEST Accu  0.893
# accuracy = 0.892807
# mean IU  = 0.580688
#     class # 0 accuracy = 0.987795
#     class # 1 accuracy = 0.843578
#     class # 2 accuracy = 0.611863
#     class # 3 accuracy = 0.972273
#     class # 4 accuracy = 0.846516
#     class # 5 accuracy = 0.814917
#     class # 6 accuracy = 0.504912
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.987500
#     class # 9 accuracy = 0.903249
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.341109
# (1, 360, 480, 12)
# Image Index 215: TEST Loss 0.997, TEST Accu  0.896
# accuracy = 0.896175
# mean IU  = 0.502361
#     class # 0 accuracy = 0.991675
#     class # 1 accuracy = 0.963002
#     class # 2 accuracy = 0.603320
#     class # 3 accuracy = 0.996478
#     class # 4 accuracy = 0.221085
#     class # 5 accuracy = 0.445672
#     class # 6 accuracy = 0.685911
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.983150
#     class # 9 accuracy = 0.000000
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.441762
# (1, 360, 480, 12)
# Image Index 216: TEST Loss 1.682, TEST Accu  0.840
# accuracy = 0.839977
# mean IU  = 0.455860
#     class # 0 accuracy = 0.985951
#     class # 1 accuracy = 0.972237
#     class # 2 accuracy = 0.653388
#     class # 3 accuracy = 0.994204
#     class # 4 accuracy = 0.229830
#     class # 5 accuracy = 0.370301
#     class # 6 accuracy = 0.301131
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.769304
#     class # 9 accuracy = 0.869817
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.340464
# (1, 360, 480, 12)
# Image Index 217: TEST Loss 0.713, TEST Accu  0.889
# accuracy = 0.888872
# mean IU  = 0.428367
#     class # 0 accuracy = 0.980732
#     class # 1 accuracy = 0.938282
#     class # 2 accuracy = 0.058524
#     class # 3 accuracy = 0.992279
#     class # 4 accuracy = 0.819382
#     class # 5 accuracy = 0.445417
#     class # 6 accuracy = 0.036771
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.956897
#     class # 9 accuracy = 0.651125
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.315871
# (1, 360, 480, 12)
# Image Index 218: TEST Loss 0.716, TEST Accu  0.891
# accuracy = 0.890897
# mean IU  = 0.440281
#     class # 0 accuracy = 0.974622
#     class # 1 accuracy = 0.933092
#     class # 2 accuracy = 0.100671
#     class # 3 accuracy = 0.990339
#     class # 4 accuracy = 0.945739
#     class # 5 accuracy = 0.679784
#     class # 6 accuracy = 0.869609
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.000000
#     class # 9 accuracy = 0.136842
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.333079
# (1, 360, 480, 12)
# Image Index 219: TEST Loss 0.548, TEST Accu  0.908
# accuracy = 0.907795
# mean IU  = 0.523026
#     class # 0 accuracy = 0.968697
#     class # 1 accuracy = 0.914299
#     class # 2 accuracy = 0.344030
#     class # 3 accuracy = 0.993103
#     class # 4 accuracy = 0.846987
#     class # 5 accuracy = 0.768747
#     class # 6 accuracy = 0.161850
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.000000
#     class # 9 accuracy = 0.892977
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.344955
# (1, 360, 480, 12)
# Image Index 220: TEST Loss 0.893, TEST Accu  0.867
# accuracy = 0.866788
# mean IU  = 0.432063
#     class # 0 accuracy = 0.930691
#     class # 1 accuracy = 0.890322
#     class # 2 accuracy = 0.293333
#     class # 3 accuracy = 0.986778
#     class # 4 accuracy = 0.762964
#     class # 5 accuracy = 0.711187
#     class # 6 accuracy = 0.502082
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.000000
#     class # 9 accuracy = 0.502183
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.396298
# (1, 360, 480, 12)
# Image Index 221: TEST Loss 2.748, TEST Accu  0.730
# accuracy = 0.729896
# mean IU  = 0.367441
#     class # 0 accuracy = 0.840307
#     class # 1 accuracy = 0.742042
#     class # 2 accuracy = 0.196577
#     class # 3 accuracy = 0.984688
#     class # 4 accuracy = 0.186492
#     class # 5 accuracy = 0.614925
#     class # 6 accuracy = 0.696057
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.143498
#     class # 9 accuracy = 0.645783
#     class # 10 accuracy = 0.371314
#     class # 11 accuracy = 0.134106
# (1, 360, 480, 12)
# Image Index 222: TEST Loss 0.788, TEST Accu  0.884
# accuracy = 0.883756
# mean IU  = 0.521106
#     class # 0 accuracy = 0.931125
#     class # 1 accuracy = 0.896396
#     class # 2 accuracy = 0.600000
#     class # 3 accuracy = 0.987162
#     class # 4 accuracy = 0.982335
#     class # 5 accuracy = 0.759482
#     class # 6 accuracy = 0.213816
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.346510
#     class # 9 accuracy = 0.820728
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.290847
# (1, 360, 480, 12)
# Image Index 223: TEST Loss 1.643, TEST Accu  0.828
# accuracy = 0.827975
# mean IU  = 0.446860
#     class # 0 accuracy = 0.928122
#     class # 1 accuracy = 0.799766
#     class # 2 accuracy = 0.597754
#     class # 3 accuracy = 0.983925
#     class # 4 accuracy = 0.959600
#     class # 5 accuracy = 0.897154
#     class # 6 accuracy = 0.070526
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.506726
#     class # 9 accuracy = 0.640227
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.135805
# (1, 360, 480, 12)
# Image Index 224: TEST Loss 0.770, TEST Accu  0.889
# accuracy = 0.888993
# mean IU  = 0.503748
#     class # 0 accuracy = 0.947398
#     class # 1 accuracy = 0.886625
#     class # 2 accuracy = 0.065753
#     class # 3 accuracy = 0.987452
#     class # 4 accuracy = 0.982677
#     class # 5 accuracy = 0.909879
#     class # 6 accuracy = 0.526087
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.952388
#     class # 9 accuracy = 0.539315
#     class # 10 accuracy = 0.010101
#     class # 11 accuracy = 0.226415
# (1, 360, 480, 12)
# Image Index 225: TEST Loss 0.678, TEST Accu  0.894
# accuracy = 0.893883
# mean IU  = 0.563281
#     class # 0 accuracy = 0.972550
#     class # 1 accuracy = 0.869588
#     class # 2 accuracy = 0.054502
#     class # 3 accuracy = 0.984821
#     class # 4 accuracy = 0.739231
#     class # 5 accuracy = 0.891113
#     class # 6 accuracy = 0.626747
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.681633
#     class # 9 accuracy = 0.775142
#     class # 10 accuracy = 0.919492
#     class # 11 accuracy = 0.526623
# (1, 360, 480, 12)
# Image Index 226: TEST Loss 1.049, TEST Accu  0.869
# accuracy = 0.869016
# mean IU  = 0.570306
#     class # 0 accuracy = 0.958570
#     class # 1 accuracy = 0.926875
#     class # 2 accuracy = 0.268315
#     class # 3 accuracy = 0.987631
#     class # 4 accuracy = 0.736856
#     class # 5 accuracy = 0.883398
#     class # 6 accuracy = 0.302836
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.819767
#     class # 9 accuracy = 0.845051
#     class # 10 accuracy = 0.969167
#     class # 11 accuracy = 0.223246
# (1, 360, 480, 12)
# Image Index 227: TEST Loss 1.012, TEST Accu  0.845
# accuracy = 0.844983
# mean IU  = 0.428967
#     class # 0 accuracy = 0.991636
#     class # 1 accuracy = 0.776532
#     class # 2 accuracy = 0.565686
#     class # 3 accuracy = 0.981589
#     class # 4 accuracy = 0.673272
#     class # 5 accuracy = 0.390408
#     class # 6 accuracy = 0.619718
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.612676
#     class # 9 accuracy = 0.707841
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.314209
# (1, 360, 480, 12)
# Image Index 228: TEST Loss 1.151, TEST Accu  0.840
# accuracy = 0.839988
# mean IU  = 0.435845
#     class # 0 accuracy = 0.995607
#     class # 1 accuracy = 0.850654
#     class # 2 accuracy = 0.438881
#     class # 3 accuracy = 0.989491
#     class # 4 accuracy = 0.571613
#     class # 5 accuracy = 0.725193
#     class # 6 accuracy = 0.651185
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.904348
#     class # 9 accuracy = 0.094782
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.228855
# (1, 360, 480, 12)
# Image Index 229: TEST Loss 1.907, TEST Accu  0.791
# accuracy = 0.790914
# mean IU  = 0.426902
#     class # 0 accuracy = 0.991588
#     class # 1 accuracy = 0.631135
#     class # 2 accuracy = 0.518599
#     class # 3 accuracy = 0.990381
#     class # 4 accuracy = 0.619598
#     class # 5 accuracy = 0.827590
#     class # 6 accuracy = 0.283172
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.950472
#     class # 9 accuracy = 0.029382
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.347092
# (1, 360, 480, 12)
# Image Index 230: TEST Loss 2.585, TEST Accu  0.755
# accuracy = 0.755069
# mean IU  = 0.392887
#     class # 0 accuracy = 0.984757
#     class # 1 accuracy = 0.836520
#     class # 2 accuracy = 0.618280
#     class # 3 accuracy = 0.997078
#     class # 4 accuracy = 0.183402
#     class # 5 accuracy = 0.883370
#     class # 6 accuracy = 0.138721
#     class # 7 accuracy = 0.052321
#     class # 8 accuracy = 0.978474
#     class # 9 accuracy = 0.000000
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.390772
# (1, 360, 480, 12)
# Image Index 231: TEST Loss 3.252, TEST Accu  0.705
# accuracy = 0.704722
# mean IU  = 0.402265
#     class # 0 accuracy = 0.984244
#     class # 1 accuracy = 0.689043
#     class # 2 accuracy = 0.358601
#     class # 3 accuracy = 0.991831
#     class # 4 accuracy = 0.230992
#     class # 5 accuracy = 0.929112
#     class # 6 accuracy = 0.729825
#     class # 7 accuracy = 0.072140
#     class # 8 accuracy = 0.970452
#     class # 9 accuracy = 0.000000
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.151992
# (1, 360, 480, 12)
# Image Index 232: TEST Loss 1.551, TEST Accu  0.840
# accuracy = 0.840179
# mean IU  = 0.438961
#     class # 0 accuracy = 0.996088
#     class # 1 accuracy = 0.863029
#     class # 2 accuracy = 0.452381
#     class # 3 accuracy = 0.988990
#     class # 4 accuracy = 0.329791
#     class # 5 accuracy = 0.000000
#     class # 6 accuracy = 0.097468
#     class # 7 accuracy = 0.000000
#     class # 8 accuracy = 0.942130
#     class # 9 accuracy = 0.000000
#     class # 10 accuracy = 0.000000
#     class # 11 accuracy = 0.260304
# Total Accuracy for test image:  0.853945120013
# Total MoI for test images:  [ 0.91246366  0.7621919   0.28400925  0.86021417  0.56138265  0.71780266
#   0.35499998  0.25641229  0.76511322  0.50374737  0.53235216  0.32103079]
# mean MoI for test images:  0.569310008029
# 0.85394512001271661

# %%
## see SegNet class and visual_results method for implementation
SegNet().visual_results(dataset_type = "TRAIN", images_index = 2, FLAG_MAX_VOTE = False)
display_color_legend()
# Out:
# VGG parameter loaded
# INFO:tensorflow:Restoring parameters from ./segnet_vgg_bayes_MFL_17000/model.ckpt-17000
# 367 CamVid test images are loaded

# %% [markdown]
# ## Test dataset (233 images)

# %%
# Index of the image with the worst global accuracy: 62
# Index of the image with an average global accuracy: 66
# Index of the image with the best global accuracy: 198
SegNet().visual_results("TEST", [62,66,198], False)
display_color_legend()
# Out:
# VGG parameter loaded
# INFO:tensorflow:Restoring parameters from ./segnet_vgg_bayes_MFL_17000/model.ckpt-17000
# 233 CamVid test images are loaded
